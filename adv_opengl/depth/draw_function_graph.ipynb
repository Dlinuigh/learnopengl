# %%
from sage.plot.plot import plot

# %%
near=1
far=50
f = (x-near)/(far-near)
p = plot(f, (x, 1, 50),
        axes_labels=['z', 'depth(z)'],
        title='near=1 far=50')
p.show()
p.save('linear.png')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
near=1
far=50
f = (1/x-1/near)/(1/far-1/near)
p = plot(f, (x, 1, 10),
        axes_labels=['z', 'depth(z)'],
        title='near=1 far=50')
p.show()
p.save('non_linear.png')
# Out:
# Graphics object consisting of 1 graphics primitive
